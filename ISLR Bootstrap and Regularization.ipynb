# %% [markdown]
# ## Bootstrap for Estimating Standard Errors of Logistic Regression Coefficients

# %%
import os
os.chdir("/Users/darrenz/Downloads")

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.linear_model import Lasso, LassoCV

# %matplotlib inline
sns.set_style("darkgrid")

# %%
df = pd.read_csv('Default.csv')
df
# Out:
#       Unnamed: 0 default student      balance       income
# 0              1      No      No   729.526495  44361.62507
# 1              2      No     Yes   817.180407  12106.13470
# 2              3      No      No  1073.549164  31767.13895
# 3              4      No      No   529.250605  35704.49394
# 4              5      No      No   785.655883  38463.49588
# ...          ...     ...     ...          ...          ...
# 9995        9996      No      No   711.555020  52992.37891
# 9996        9997      No      No   757.962918  19660.72177
# 9997        9998      No      No   845.411989  58636.15698
# 9998        9999      No      No  1569.009053  36669.11236
# 9999       10000      No     Yes   200.922183  16862.95232
#
# [10000 rows x 5 columns]

# %% [markdown]
# ## a)

# %%
formula = 'default ~ income + balance'
default_glm = smf.glm(formula, data=df, family=sm.families.Binomial()).fit()
print(default_glm.bse)
default_glm.summary()
# Out:
# Intercept    0.434772
# income       0.000005
# balance      0.000227
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                         Generalized Linear Model Regression Results
# ===========================================================================================
# Dep. Variable:     ['default[No]', 'default[Yes]']   No. Observations:                10000
# Model:                                         GLM   Df Residuals:                     9997
# Model Family:                             Binomial   Df Model:                            2
# Link Function:                               logit   Scale:                          1.0000
# Method:                                       IRLS   Log-Likelihood:                -789.48
# Date:                             Thu, 14 Apr 2022   Deviance:                       1579.0
# Time:                                     17:18:41   Pearson chi2:                 6.95e+03
# No. Iterations:                                  9
# Covariance Type:                         nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     11.5405      0.435     26.544      0.000      10.688      12.393
# income     -2.081e-05   4.99e-06     -4.174      0.000   -3.06e-05    -1.1e-05
# balance       -0.0056      0.000    -24.835      0.000      -0.006      -0.005
# ==============================================================================
# """

# %% [markdown]
# From the summary of the logistic regression, we can see the coefficient of `income` is -2.081e-05 with an estimated standard error of 4.99e-06. The coefficient of `balance` is -0.0056 with an estimated standard error of 0.000227.

# %% [markdown]
# ## b)

# %%
def boot_fn(df, index): 
    formula = 'default ~ income + balance'
    df_select = df.loc[index]
    df_glm = smf.glm(formula, data=df_select, family=sm.families.Binomial()).fit()
    return df_glm.params[1:3]

# %%
index_count = random.randint(1,10000)

df_sample = df.sample(n = index_count, replace = True) 
df_index = np.array(df_sample.index)

boot_fn(df, df_index) #test the function above
# Out:
# income    -0.000020
# balance   -0.005695
# dtype: float64

# %% [markdown]
# ## c)

# %%
np.random.seed(123) #set the seed for consistent results

# %%
from sklearn.utils import resample

def boot(data, fn, R): #define a function that works as the boot() function in Rstudio
    df_co = pd.DataFrame()
    list1 = []
    list2 = []
    list_se = []
    
    for num in range(R):
        df_resample = resample(data, replace = True) #we use the same size of the dataset for each bootstrap sample
        df_index = np.array(df_resample.index)
        list1.append(list(boot_fn(data, df_index))[0])
        list2.append(list(boot_fn(data, df_index))[1])
    df_co['income_coef'] = list1
    df_co['balance_coef'] = list2
    
    list_se.append(df_co['income_coef'].std())
    list_se.append(df_co['balance_coef'].std())
    
    return list_se

# %%
boot(df, boot_fn, 2000) #choose a number of replicates of 3000 to test the function
# Out:
# [4.787838502790651e-06, 0.00022592076250269424]

# %% [markdown]
# ## d)

# %% [markdown]
# By comparison, we can see that the standard error obtained by bootstrapping is very much similar to the standard error of the logistic regression model.

# %% [markdown]
# ## Lasso, Ridge, and Least Squares

# %% [markdown]
# ## a)

# %%
df1 = pd.read_csv('College.csv')
df1.rename(columns={'Unnamed: 0': 'CollegeName'}, inplace = True)
df1.set_index('CollegeName', inplace = True) #Data preprocessing
df1
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# CollegeName
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# CollegeName
# Abilene Christian University           52         2885          537      7440
# Adelphi University                     29         2683         1227     12280
# Adrian College                         50         1036           99     11250
# Agnes Scott College                    89          510           63     12960
# Alaska Pacific University              44          249          869      7560
# ...                                   ...          ...          ...       ...
# Worcester State College                26         3089         2029      6797
# Xavier University                      47         2849         1107     11520
# Xavier University of Louisiana         61         2793          166      6900
# Yale University                        99         5217           83     19840
# York College of Pennsylvania           63         2988         1726      4990
#
#                                 Room.Board  Books  Personal  PhD  Terminal  \
# CollegeName
# Abilene Christian University          3300    450      2200   70        78
# Adelphi University                    6450    750      1500   29        30
# Adrian College                        3750    400      1165   53        66
# Agnes Scott College                   5450    450       875   92        97
# Alaska Pacific University             4120    800      1500   76        72
# ...                                    ...    ...       ...  ...       ...
# Worcester State College               3900    500      1200   60        60
# Xavier University                     4960    600      1250   73        75
# Xavier University of Louisiana        4200    617       781   67        75
# Yale University                       6510    630      2115   96        96
# York College of Pennsylvania          3560    500      1250   75        75
#
#                                 S.F.Ratio  perc.alumni  Expend  Grad.Rate
# CollegeName
# Abilene Christian University         18.1           12    7041         60
# Adelphi University                   12.2           16   10527         56
# Adrian College                       12.9           30    8735         54
# Agnes Scott College                   7.7           37   19016         59
# Alaska Pacific University            11.9            2   10922         15
# ...                                   ...          ...     ...        ...
# Worcester State College              21.0           14    4469         40
# Xavier University                    13.3           31    9189         83
# Xavier University of Louisiana       14.4           20    8323         49
# Yale University                       5.8           49   40386         99
# York College of Pennsylvania         18.1           28    4509         99
#
# [777 rows x 18 columns]

# %%
df1 = pd.get_dummies(df1, columns=['Private'], drop_first=True) #binary coding for the variable 'private'
df1
# Out:
#                                  Apps  Accept  Enroll  Top10perc  Top25perc  \
# CollegeName
# Abilene Christian University     1660    1232     721         23         52
# Adelphi University               2186    1924     512         16         29
# Adrian College                   1428    1097     336         22         50
# Agnes Scott College               417     349     137         60         89
# Alaska Pacific University         193     146      55         16         44
# ...                               ...     ...     ...        ...        ...
# Worcester State College          2197    1515     543          4         26
# Xavier University                1959    1805     695         24         47
# Xavier University of Louisiana   2097    1915     695         34         61
# Yale University                 10705    2453    1317         95         99
# York College of Pennsylvania     2989    1855     691         28         63
#
#                                 F.Undergrad  P.Undergrad  Outstate  \
# CollegeName
# Abilene Christian University           2885          537      7440
# Adelphi University                     2683         1227     12280
# Adrian College                         1036           99     11250
# Agnes Scott College                     510           63     12960
# Alaska Pacific University               249          869      7560
# ...                                     ...          ...       ...
# Worcester State College                3089         2029      6797
# Xavier University                      2849         1107     11520
# Xavier University of Louisiana         2793          166      6900
# Yale University                        5217           83     19840
# York College of Pennsylvania           2988         1726      4990
#
#                                 Room.Board  Books  Personal  PhD  Terminal  \
# CollegeName
# Abilene Christian University          3300    450      2200   70        78
# Adelphi University                    6450    750      1500   29        30
# Adrian College                        3750    400      1165   53        66
# Agnes Scott College                   5450    450       875   92        97
# Alaska Pacific University             4120    800      1500   76        72
# ...                                    ...    ...       ...  ...       ...
# Worcester State College               3900    500      1200   60        60
# Xavier University                     4960    600      1250   73        75
# Xavier University of Louisiana        4200    617       781   67        75
# Yale University                       6510    630      2115   96        96
# York College of Pennsylvania          3560    500      1250   75        75
#
#                                 S.F.Ratio  perc.alumni  Expend  Grad.Rate  \
# CollegeName
# Abilene Christian University         18.1           12    7041         60
# Adelphi University                   12.2           16   10527         56
# Adrian College                       12.9           30    8735         54
# Agnes Scott College                   7.7           37   19016         59
# Alaska Pacific University            11.9            2   10922         15
# ...                                   ...          ...     ...        ...
# Worcester State College              21.0           14    4469         40
# Xavier University                    13.3           31    9189         83
# Xavier University of Louisiana       14.4           20    8323         49
# Yale University                       5.8           49   40386         99
# York College of Pennsylvania         18.1           28    4509         99
#
#                                 Private_Yes
# CollegeName
# Abilene Christian University              1
# Adelphi University                        1
# Adrian College                            1
# Agnes Scott College                       1
# Alaska Pacific University                 1
# ...                                     ...
# Worcester State College                   0
# Xavier University                         1
# Xavier University of Louisiana            1
# Yale University                           1
# York College of Pennsylvania              1
#
# [777 rows x 18 columns]

# %%
cols = ['Accept',
 'Enroll',
 'Top10perc',
 'Top25perc',
 'F.Undergrad',
 'P.Undergrad',
 'Outstate',
 'Room.Board',
 'Books',
 'Personal',
 'PhD',
 'Terminal',
 'S.F.Ratio',
 'perc.alumni',
 'Expend',
 'Grad.Rate',
 'Private_Yes',
 'Apps']

df1 = df1[cols] #reorder the column names of data frame
df1
# Out:
#                                 Accept  Enroll  Top10perc  Top25perc  \
# CollegeName
# Abilene Christian University      1232     721         23         52
# Adelphi University                1924     512         16         29
# Adrian College                    1097     336         22         50
# Agnes Scott College                349     137         60         89
# Alaska Pacific University          146      55         16         44
# ...                                ...     ...        ...        ...
# Worcester State College           1515     543          4         26
# Xavier University                 1805     695         24         47
# Xavier University of Louisiana    1915     695         34         61
# Yale University                   2453    1317         95         99
# York College of Pennsylvania      1855     691         28         63
#
#                                 F.Undergrad  P.Undergrad  Outstate  \
# CollegeName
# Abilene Christian University           2885          537      7440
# Adelphi University                     2683         1227     12280
# Adrian College                         1036           99     11250
# Agnes Scott College                     510           63     12960
# Alaska Pacific University               249          869      7560
# ...                                     ...          ...       ...
# Worcester State College                3089         2029      6797
# Xavier University                      2849         1107     11520
# Xavier University of Louisiana         2793          166      6900
# Yale University                        5217           83     19840
# York College of Pennsylvania           2988         1726      4990
#
#                                 Room.Board  Books  Personal  PhD  Terminal  \
# CollegeName
# Abilene Christian University          3300    450      2200   70        78
# Adelphi University                    6450    750      1500   29        30
# Adrian College                        3750    400      1165   53        66
# Agnes Scott College                   5450    450       875   92        97
# Alaska Pacific University             4120    800      1500   76        72
# ...                                    ...    ...       ...  ...       ...
# Worcester State College               3900    500      1200   60        60
# Xavier University                     4960    600      1250   73        75
# Xavier University of Louisiana        4200    617       781   67        75
# Yale University                       6510    630      2115   96        96
# York College of Pennsylvania          3560    500      1250   75        75
#
#                                 S.F.Ratio  perc.alumni  Expend  Grad.Rate  \
# CollegeName
# Abilene Christian University         18.1           12    7041         60
# Adelphi University                   12.2           16   10527         56
# Adrian College                       12.9           30    8735         54
# Agnes Scott College                   7.7           37   19016         59
# Alaska Pacific University            11.9            2   10922         15
# ...                                   ...          ...     ...        ...
# Worcester State College              21.0           14    4469         40
# Xavier University                    13.3           31    9189         83
# Xavier University of Louisiana       14.4           20    8323         49
# Yale University                       5.8           49   40386         99
# York College of Pennsylvania         18.1           28    4509         99
#
#                                 Private_Yes   Apps
# CollegeName
# Abilene Christian University              1   1660
# Adelphi University                        1   2186
# Adrian College                            1   1428
# Agnes Scott College                       1    417
# Alaska Pacific University                 1    193
# ...                                     ...    ...
# Worcester State College                   0   2197
# Xavier University                         1   1959
# Xavier University of Louisiana            1   2097
# Yale University                           1  10705
# York College of Pennsylvania              1   2989
#
# [777 rows x 18 columns]

# %%
df1.corr()
# Out:
#                Accept    Enroll  Top10perc  Top25perc  F.Undergrad  \
# Accept       1.000000  0.911637   0.192447   0.247476     0.874223
# Enroll       0.911637  1.000000   0.181294   0.226745     0.964640
# Top10perc    0.192447  0.181294   1.000000   0.891995     0.141289
# Top25perc    0.247476  0.226745   0.891995   1.000000     0.199445
# F.Undergrad  0.874223  0.964640   0.141289   0.199445     1.000000
# P.Undergrad  0.441271  0.513069  -0.105356  -0.053577     0.570512
# Outstate    -0.025755 -0.155477   0.562331   0.489394    -0.215742
# Room.Board   0.090899 -0.040232   0.371480   0.331490    -0.068890
# Books        0.113525  0.112711   0.118858   0.115527     0.115550
# Personal     0.200989  0.280929  -0.093316  -0.080810     0.317200
# PhD          0.355758  0.331469   0.531828   0.545862     0.318337
# Terminal     0.337583  0.308274   0.491135   0.524749     0.300019
# S.F.Ratio    0.176229  0.237271  -0.384875  -0.294629     0.279703
# perc.alumni -0.159990 -0.180794   0.455485   0.417864    -0.229462
# Expend       0.124717  0.064169   0.660913   0.527447     0.018652
# Grad.Rate    0.067313 -0.022341   0.494989   0.477281    -0.078773
# Private_Yes -0.475252 -0.567908   0.164132   0.095752    -0.615561
# Apps         0.943451  0.846822   0.338834   0.351640     0.814491
#
#              P.Undergrad  Outstate  Room.Board     Books  Personal       PhD  \
# Accept          0.441271 -0.025755    0.090899  0.113525  0.200989  0.355758
# Enroll          0.513069 -0.155477   -0.040232  0.112711  0.280929  0.331469
# Top10perc      -0.105356  0.562331    0.371480  0.118858 -0.093316  0.531828
# Top25perc      -0.053577  0.489394    0.331490  0.115527 -0.080810  0.545862
# F.Undergrad     0.570512 -0.215742   -0.068890  0.115550  0.317200  0.318337
# P.Undergrad     1.000000 -0.253512   -0.061326  0.081200  0.319882  0.149114
# Outstate       -0.253512  1.000000    0.654256  0.038855 -0.299087  0.382982
# Room.Board     -0.061326  0.654256    1.000000  0.127963 -0.199428  0.329202
# Books           0.081200  0.038855    0.127963  1.000000  0.179295  0.026906
# Personal        0.319882 -0.299087   -0.199428  0.179295  1.000000 -0.010936
# PhD             0.149114  0.382982    0.329202  0.026906 -0.010936  1.000000
# Terminal        0.141904  0.407983    0.374540  0.099955 -0.030613  0.849587
# S.F.Ratio       0.232531 -0.554821   -0.362628 -0.031929  0.136345 -0.130530
# perc.alumni    -0.280792  0.566262    0.272363 -0.040208 -0.285968  0.249009
# Expend         -0.083568  0.672779    0.501739  0.112409 -0.097892  0.432762
# Grad.Rate      -0.257001  0.571290    0.424942  0.001061 -0.269344  0.305038
# Private_Yes    -0.452088  0.552650    0.340532 -0.018549 -0.304485 -0.156714
# Apps            0.398264  0.050159    0.164939  0.132559  0.178731  0.390697
#
#              Terminal  S.F.Ratio  perc.alumni    Expend  Grad.Rate  \
# Accept       0.337583   0.176229    -0.159990  0.124717   0.067313
# Enroll       0.308274   0.237271    -0.180794  0.064169  -0.022341
# Top10perc    0.491135  -0.384875     0.455485  0.660913   0.494989
# Top25perc    0.524749  -0.294629     0.417864  0.527447   0.477281
# F.Undergrad  0.300019   0.279703    -0.229462  0.018652  -0.078773
# P.Undergrad  0.141904   0.232531    -0.280792 -0.083568  -0.257001
# Outstate     0.407983  -0.554821     0.566262  0.672779   0.571290
# Room.Board   0.374540  -0.362628     0.272363  0.501739   0.424942
# Books        0.099955  -0.031929    -0.040208  0.112409   0.001061
# Personal    -0.030613   0.136345    -0.285968 -0.097892  -0.269344
# PhD          0.849587  -0.130530     0.249009  0.432762   0.305038
# Terminal     1.000000  -0.160104     0.267130  0.438799   0.289527
# S.F.Ratio   -0.160104   1.000000    -0.402929 -0.583832  -0.306710
# perc.alumni  0.267130  -0.402929     1.000000  0.417712   0.490898
# Expend       0.438799  -0.583832     0.417712  1.000000   0.390343
# Grad.Rate    0.289527  -0.306710     0.490898  0.390343   1.000000
# Private_Yes -0.129620  -0.472205     0.414775  0.258461   0.336162
# Apps         0.369491   0.095633    -0.090226  0.259592   0.146755
#
#              Private_Yes      Apps
# Accept         -0.475252  0.943451
# Enroll         -0.567908  0.846822
# Top10perc       0.164132  0.338834
# Top25perc       0.095752  0.351640
# F.Undergrad    -0.615561  0.814491
# P.Undergrad    -0.452088  0.398264
# Outstate        0.552650  0.050159
# Room.Board      0.340532  0.164939
# Books          -0.018549  0.132559
# Personal       -0.304485  0.178731
# PhD            -0.156714  0.390697
# Terminal       -0.129620  0.369491
# S.F.Ratio      -0.472205  0.095633
# perc.alumni     0.414775 -0.090226
# Expend          0.258461  0.259592
# Grad.Rate       0.336162  0.146755
# Private_Yes     1.000000 -0.432095
# Apps           -0.432095  1.000000

# %% [markdown]
# We create a correlation matrix to see if there exists any multicollinearity. We see that there is a high correlation between `Accept` and `Enroll` which in practice we should drop one variable, but according to question we need to run the model using all other variables.

# %%
train, test = train_test_split(df1, test_size = 0.3) #train test with a 70% to 30% ratio
X_train = train.iloc[0:,0:17]
y_train = train['Apps']
X_test = test.iloc[0:,0:17]
y_test = test['Apps']
X_train
# Out:
#                                       Accept  Enroll  Top10perc  Top25perc  \
# CollegeName
# Prairie View A. and M. University       2234    1061         10         22
# Trinity University                      1818     601         62         93
# Trinity College CT                      1798     478         46         84
# Wake Forest University                  2392     903         75         88
# Seton Hall University                   3565    1000         16         36
# ...                                      ...     ...        ...        ...
# SUNY at Buffalo                         9649    3087         36        100
# Eastern Connecticut State University    1493     564         14         50
# Immaculata College                       253     103         16         44
# Hofstra University                      5860    1349         25         63
# Bellarmine College                       707     308         39         63
#
#                                       F.Undergrad  P.Undergrad  Outstate  \
# CollegeName
# Prairie View A. and M. University            4564          448      4290
# Trinity University                           2110           95     12240
# Trinity College CT                           1737          244     18810
# Wake Forest University                       3499          172     13850
# Seton Hall University                        4384         1530     12000
# ...                                           ...          ...       ...
# SUNY at Buffalo                             13963         3124      6550
# Eastern Connecticut State University         2766         1531      5962
# Immaculata College                            494         1305     10000
# Hofstra University                           6534         1350     11600
# Bellarmine College                           1198          605      8840
#
#                                       Room.Board  Books  Personal  PhD  \
# CollegeName
# Prairie View A. and M. University           3500    598      1582   55
# Trinity University                          5150    500       490   94
# Trinity College CT                          5690    500       680   91
# Wake Forest University                      4360    500      1250   95
# Seton Hall University                       6484    650      1000   81
# ...                                          ...    ...       ...  ...
# SUNY at Buffalo                             4731    708       957   90
# Eastern Connecticut State University        4316    650       500   71
# Immaculata College                          5364    500      1000   56
# Hofstra University                          5920   1000      1000   81
# Bellarmine College                          2950    750      1290   74
#
#                                       Terminal  S.F.Ratio  perc.alumni  \
# CollegeName
# Prairie View A. and M. University           93       19.4            1
# Trinity University                          96        9.6           20
# Trinity College CT                          96       10.4           48
# Wake Forest University                      97        4.3           37
# Seton Hall University                       84       14.4           15
# ...                                        ...        ...          ...
# SUNY at Buffalo                             97       13.6           15
# Eastern Connecticut State University        76       16.9           14
# Immaculata College                          64       11.2           33
# Hofstra University                          90       13.9           10
# Bellarmine College                          82       13.1           31
#
#                                       Expend  Grad.Rate  Private_Yes
# CollegeName
# Prairie View A. and M. University       5967         35            0
# Trinity University                     14703         93            1
# Trinity College CT                     18034         91            1
# Wake Forest University                 41766         89            1
# Seton Hall University                  10080         64            1
# ...                                      ...        ...          ...
# SUNY at Buffalo                        11177         56            0
# Eastern Connecticut State University    5719         50            0
# Immaculata College                      7305         69            1
# Hofstra University                     10093         60            1
# Bellarmine College                      6668         84            1
#
# [543 rows x 17 columns]

# %% [markdown]
# ## b)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

test_error = mean_squared_error(y_test, y_pred)
test_error
# Out:
# 1203743.8910864787

# %% [markdown]
# After fitting a linear regression using the scikitlearn package, we see that the test error generated is `1203743.8910864787`.

# %% [markdown]
# ## c)

# %%
alpha_list = np.logspace(-20, 20, 10000) #create the list of alphas we want to cross validate
model_Ridge = RidgeCV(alphas = alpha_list)
model_Ridge.fit(X_train, y_train)
y_ridgepred = model_Ridge.predict(X_test)

ridge_test_error = mean_squared_error(y_test, y_ridgepred)
ridge_test_error
# Out:
# 1204740.4020278968

# %% [markdown]
# After fitting a ridge linear regression using the scikitlearn package and cross validating the values of alpha, we see that the test error generated is `1204740.4020278968`.

# %% [markdown]
# ## d)

# %%
alpha_list = np.logspace(-20, 20, 10000) #create the list of alphas we want to cross validate
model_Lasso = LassoCV(alphas = alpha_list)
model_Lasso.fit(X_train, y_train)
y_lassopred = model_Lasso.predict(X_test)

lasso_test_error = mean_squared_error(y_test, y_lassopred)
lasso_test_error
# Out:
# 1203503.8700627144

# %% [markdown]
# After fitting a lasso linear regression using the scikitlearn package and cross validating the values of alpha, we see that the test error generated is `1203503.8700627144`.

# %%
list_name = list(df1)
list_name.pop()
list_coef = list(model_Lasso.fit(X_train, y_train).coef_)
list_icp = model_Lasso.fit(X_train, y_train).intercept_

list_name.insert(0, 'Intercept')
list_coef.insert(0, list_icp)

df_coef = df = pd.DataFrame({'Variable': list_name, 'Coefficient': list_coef})
df_coef
# Out:
#        Variable  Coefficient
# 0     Intercept    -1.316546
# 1        Accept     1.686477
# 2        Enroll    -1.045237
# 3     Top10perc    59.512495
# 4     Top25perc   -21.955398
# 5   F.Undergrad     0.061058
# 6   P.Undergrad     0.066237
# 7      Outstate    -0.086717
# 8    Room.Board     0.086307
# 9         Books     0.047809
# 10     Personal    -0.054921
# 11          PhD    -9.996589
# 12     Terminal    -2.387094
# 13    S.F.Ratio     7.456300
# 14  perc.alumni     0.650725
# 15       Expend     0.070912
# 16    Grad.Rate    10.354599
# 17  Private_Yes  -381.711981

# %% [markdown]
# Here are the parameter estimates for the lasso regression model.

# %% [markdown]
# ## g)

# %%
lr_acc = r2_score(y_test, y_pred)
ridge_acc = r2_score(y_test, y_ridgepred)
lasso_acc = r2_score(y_test, y_lassopred)

print('Accuracy score for linear regression is: ' + str(lr_acc))
print('Accuracy score for ridge regression is: ' + str(ridge_acc))
print('Accuracy score for lasso regression is: ' + str(lasso_acc))
# Out:
# Accuracy score for linear regression is: 0.888163962060382
# Accuracy score for ridge regression is: 0.8880713793803975
# Accuracy score for lasso regression is: 0.8881862616546052

# %% [markdown]
# We can see that using the R squared as a accuracy metric for the three models, each of them achieve an accuracy score around 0.89, which indicates that the prediction is pretty accurate. Here is a summary of results obtained: least squares regression test error: `1203743.8910864787`; ridge regression test error: `1204740.4020278968`; lasso regression test error: `1203503.8700627144`. We see that there is not much difference between the test errors of the three approaches.
